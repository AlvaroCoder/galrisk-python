# %%
from code_app.obtener_precedentes import obtener_precedentes_completos
from code_app.filtrar_raices import filtrar_valores_raiz
from code_app.simular_impacto_raices import simular_impacto_raices
from code_app.filtrar_impactos import filtrar_mayores_impactos
from tabulate import tabulate  # pip install tabulate

# %%
ruta_excel = "/Users/alvarofelipepupuchemorales/Desktop/Proyecto Economia/assets/PALTA HASS  BCP.xlsx"
hoja_nombre = "Costos Agricolas 01 ha"
celda_objetivo = "E123"
# Conseguimos los precedentes
precedentes_totales = obtener_precedentes_completos(ruta_excel, hoja_nombre, celda_objetivo)
for p in precedentes_totales:
    print(p)
# Out:
# Costos Agricolas 01 ha!$E$45
# Costos Agricolas 01 ha!$E$46
# Costos Agricolas 01 ha!$E$48
# Costos Agricolas 01 ha!$E$53
# Costos Agricolas 01 ha!$E$55
# Costos Agricolas 01 ha!$H$95
# Costos Agricolas 01 ha!E11
# Costos Agricolas 01 ha!E120
# Costos Agricolas 01 ha!E29
# Costos Agricolas 01 ha!E30
# Costos Agricolas 01 ha!E31
# Costos Agricolas 01 ha!E32
# Costos Agricolas 01 ha!E33
# Costos Agricolas 01 ha!E34
# Costos Agricolas 01 ha!E41
# Costos Agricolas 01 ha!E46
# Costos Agricolas 01 ha!E50
# Costos Agricolas 01 ha!E53
# Costos Agricolas 01 ha!E84
# Costos Agricolas 01 ha!E85
# Costos Agricolas 01 ha!E86
# Costos Agricolas 01 ha!E87
# Costos Agricolas 01 ha!E88
# Costos Agricolas 01 ha!E89
# Costos Agricolas 01 ha!F11
# Costos Agricolas 01 ha!F120
# Costos Agricolas 01 ha!F15
# Costos Agricolas 01 ha!F22
# Costos Agricolas 01 ha!F23
# Costos Agricolas 01 ha!F31
# Costos Agricolas 01 ha!F41
# Costos Agricolas 01 ha!F84
# Costos Agricolas 01 ha!F85
# Costos Agricolas 01 ha!F86
# Costos Agricolas 01 ha!F87
# Costos Agricolas 01 ha!F88
# Costos Agricolas 01 ha!F89
# Costos Agricolas 01 ha!F98
# Costos Agricolas 01 ha!G11
# Costos Agricolas 01 ha!G120
# Costos Agricolas 01 ha!G15
# Costos Agricolas 01 ha!G16
# Costos Agricolas 01 ha!G17
# Costos Agricolas 01 ha!G19
# Costos Agricolas 01 ha!G23
# Costos Agricolas 01 ha!G24
# Costos Agricolas 01 ha!G25
# Costos Agricolas 01 ha!G26
# Costos Agricolas 01 ha!G36
# Costos Agricolas 01 ha!G37
# Costos Agricolas 01 ha!G38
# Costos Agricolas 01 ha!G39
# Costos Agricolas 01 ha!G41
# Costos Agricolas 01 ha!G57
# Costos Agricolas 01 ha!G80
# Costos Agricolas 01 ha!G81
# Costos Agricolas 01 ha!G82
# Costos Agricolas 01 ha!G83
# Costos Agricolas 01 ha!G84
# Costos Agricolas 01 ha!G85
# Costos Agricolas 01 ha!G86
# Costos Agricolas 01 ha!G87
# Costos Agricolas 01 ha!G88
# Costos Agricolas 01 ha!G89
# Costos Agricolas 01 ha!H95
# Costos Agricolas 01 ha!J94
# Costos Agricolas 01 ha!J95
# Costos Agricolas 01 ha!J96
# Costos Agricolas 01 ha!J97
# Costos Agricolas 01 ha!V11
# Costos Agricolas 01 ha!V120
# Costos Agricolas 01 ha!V15
# Costos Agricolas 01 ha!V17
# Costos Agricolas 01 ha!V18
# Costos Agricolas 01 ha!V19
# Costos Agricolas 01 ha!V23
# Costos Agricolas 01 ha!V24
# Costos Agricolas 01 ha!V26
# Costos Agricolas 01 ha!V36
# Costos Agricolas 01 ha!V37
# Costos Agricolas 01 ha!V38
# Costos Agricolas 01 ha!V39
# Costos Agricolas 01 ha!V41
# Costos Agricolas 01 ha!V45
# Costos Agricolas 01 ha!V46
# Costos Agricolas 01 ha!V48
# Costos Agricolas 01 ha!V53
# Costos Agricolas 01 ha!V55
# Costos Agricolas 01 ha!V57
# Costos Agricolas 01 ha!V58
# Costos Agricolas 01 ha!V80
# Costos Agricolas 01 ha!V81
# Costos Agricolas 01 ha!V82
# Costos Agricolas 01 ha!V83
# Costos Agricolas 01 ha!V84
# Costos Agricolas 01 ha!V85
# Costos Agricolas 01 ha!V86
# Costos Agricolas 01 ha!V87
# Costos Agricolas 01 ha!V88
# Costos Agricolas 01 ha!V89
# INSTALACION Y SIEMBRA!B10
# INSTALACION Y SIEMBRA!B19
# INSTALACION Y SIEMBRA!B23
# INSTALACION Y SIEMBRA!B26
# INSTALACION Y SIEMBRA!B28
# INSTALACION Y SIEMBRA!B8
# INSTALACION Y SIEMBRA!B9
# PALTA HASS activos!$B$6
# PALTA HASS activos!B22
# PALTA HASS activos!B28
# PALTA HASS activos!B34
# PALTA HASS activos!B38
# PALTA HASS activos!B43
# PALTA HASS activos!B47
# PALTA HASS activos!B48
# PALTA HASS activos!B49
# PALTA HASS activos!B50
# PALTA HASS activos!B52
# PALTA HASS activos!B6
# PALTA HASS activos!C22
# PALTA HASS activos!C28
# PALTA HASS activos!C34
# PALTA HASS activos!C38
# PALTA HASS activos!C43
# PALTA HASS activos!C47
# PALTA HASS activos!C48
# PALTA HASS activos!C49
# PALTA HASS activos!C50
# PALTA HASS activos!C52
# PALTA HASS activos!D22
# PALTA HASS activos!D28
# PALTA HASS activos!D34
# PALTA HASS activos!D38
# PALTA HASS activos!D43
# PALTA HASS activos!D47
# PALTA HASS activos!D48
# PALTA HASS activos!D49
# PALTA HASS activos!D50
# PALTA HASS activos!D52
# PALTA HASS activos!G34
# PALTA HASS activos!H22
# PALTA HASS activos!H26
# PALTA HASS activos!H28
# PALTA HASS activos!H36
# PALTA HASS activos!H38
# PALTA HASS activos!H43
# PALTA HASS activos!H45
# PALTA HASS activos!H47
# PALTA HASS activos!H48
# PALTA HASS activos!H49
# PALTA HASS activos!H50
# PALTA HASS activos!H52

# %%
print("="*100)

raices = filtrar_valores_raiz(ruta_excel, precedentes_totales)

print("Raíces encontradas:")
for celda, valor in raices.items():
    print(f"{celda} → {valor}")
# Out:
# ====================================================================================================
# Raíces encontradas:
# Costos Agricolas 01 ha!$E$45 → 25
# Costos Agricolas 01 ha!$E$46 → 0.9
# Costos Agricolas 01 ha!$E$53 → 1600
# Costos Agricolas 01 ha!$H$95 → 0.07
# Costos Agricolas 01 ha!E29 → 100
# Costos Agricolas 01 ha!E46 → 0.9
# Costos Agricolas 01 ha!E50 → 0.02
# Costos Agricolas 01 ha!E53 → 1600
# Costos Agricolas 01 ha!F98 → 30800
# Costos Agricolas 01 ha!G15 → 350
# Costos Agricolas 01 ha!G16 → 200
# Costos Agricolas 01 ha!G17 → 1000
# Costos Agricolas 01 ha!G19 → 121
# Costos Agricolas 01 ha!G23 → 1200
# Costos Agricolas 01 ha!G24 → 750
# Costos Agricolas 01 ha!G25 → 200
# Costos Agricolas 01 ha!G37 → 200
# Costos Agricolas 01 ha!G57 → 0
# Costos Agricolas 01 ha!G85 → 0
# Costos Agricolas 01 ha!G88 → 3800
# Costos Agricolas 01 ha!H95 → 0.07
# Costos Agricolas 01 ha!J94 → 30800
# Costos Agricolas 01 ha!V15 → 427
# Costos Agricolas 01 ha!V17 → 1734
# Costos Agricolas 01 ha!V19 → 480
# Costos Agricolas 01 ha!V23 → 2200
# Costos Agricolas 01 ha!V24 → 1200
# Costos Agricolas 01 ha!V37 → 300
# INSTALACION Y SIEMBRA!B19 → 900
# INSTALACION Y SIEMBRA!B23 → 700
# INSTALACION Y SIEMBRA!B8 → 6
# INSTALACION Y SIEMBRA!B9 → 3
# PALTA HASS activos!$B$6 → 16.52
# PALTA HASS activos!B22 → 100
# PALTA HASS activos!B28 → 3950
# PALTA HASS activos!B34 → 50000
# PALTA HASS activos!B38 → 15000
# PALTA HASS activos!B43 → 4500
# PALTA HASS activos!B47 → 45000
# PALTA HASS activos!B48 → 18500
# PALTA HASS activos!B49 → 17000
# PALTA HASS activos!B50 → 3500
# PALTA HASS activos!B6 → 16.52
# PALTA HASS activos!C34 → 0.5
# PALTA HASS activos!C38 → 0.5
# PALTA HASS activos!C47 → 0.5
# PALTA HASS activos!C48 → 0.5
# PALTA HASS activos!C49 → 0.5
# PALTA HASS activos!C50 → 0.5
# PALTA HASS activos!C52 → 1

# %%
import openpyxl
import re
from openpyxl.utils import column_index_from_string, get_column_letter

def generar_precedentes(ruta_excel, hoja_objetivo, celda_objetivo):
    """
    Genera un mapa de precedentes y fórmulas a partir de una celda objetivo en un Excel.

    Args:
        ruta_excel (str): La ruta al archivo Excel.
        hoja_objetivo (str): El nombre de la hoja en el Excel.
        celda_objetivo (str): La celda a partir de la cual se desea generar el mapa (ej. 'A1').

    Returns:
        tuple: Una tupla que contiene:
            - mapa (dict): Un diccionario donde las claves son referencias de celda (ej. 'A1')
              y los valores son funciones lambda de Python que representan la fórmula de esa celda.
              Cada lambda toma un argumento 'r' (una función de resolución para obtener valores de precedentes).
            - formulas (dict): Un diccionario donde las claves son referencias de celda y los valores
              son las fórmulas de Excel (limpias, sin '=') como cadenas.
            - raices (dict): Un diccionario donde las claves son referencias de celda y los valores
              son los valores numéricos de las celdas que no contienen fórmulas (las 'raíces' o entradas).
    """
    wb = openpyxl.load_workbook(ruta_excel, data_only=False)
    hoja = wb[hoja_objetivo]

    mapa = {}       # Almacenará las funciones lambda (fórmulas traducidas a Python)
    formulas = {}   # Almacenará las fórmulas de Excel (cadenas)
    raices = {}     # Almacenará los valores de las celdas sin fórmula (inputs)
    visitadas = set() # Para evitar bucles infinitos y reprocesamiento

    # Funciones auxiliares de Excel para simular en Python
    def npv(rate, values):
        # Asegura que 'values' sea un iterable numérico
        if not isinstance(values, (list, tuple, set)):
            if values is None: # Si no hay valores en el rango, NPV puede ser 0
                 return 0.0
            # Si es un solo valor numérico, conviértelo a lista
            try:
                values = [float(values)]
            except (ValueError, TypeError):
                raise TypeError(f"NPV values must be a list/tuple of numbers or a single number, received: {values}")

        return sum(v / (1 + rate) ** (i + 1) for i, v in enumerate(values))

    # Puedes añadir más funciones aquí si tus fórmulas las usan
    # Por ejemplo, para SUM, MAX, MIN, AVERAGE, etc.

    # Obtener fórmula de celda
    def obtener_formula(celda_ref):
        try:
            celda_obj = hoja[celda_ref]
            if celda_obj.data_type == 'f':
                return str(celda_obj.value) # Asegurarse de que es una cadena
            return None # No es una fórmula
        except KeyError:
            print(f"Advertencia: Celda {celda_ref} no encontrada en la hoja.")
            return None

    # Limpiar "=" y "+" inicial
    def limpiar_formula(formula_str):
        # Eliminar el '=' inicial si existe
        if formula_str.startswith('='):
            formula_str = formula_str[1:]
        # Eliminar el '+' inicial si existe (es común en Excel después del '=')
        if formula_str.startswith('+'):
            formula_str = formula_str[1:]
        return formula_str

    # Extraer referencias de celdas individuales y rangos
    def extraer_referencias_y_rangos(formula_str):
        # Primero, eliminar prefijos de hoja (ej. 'Hoja1'!)
        sin_hoja = re.sub(r"(?:'[^']+'|[A-Za-z0-9_]+)!", "", formula_str)
        
        # Encontrar todas las ocurrencias de referencias de celda A1 o rangos A1:B5
        # Esto captura las referencias de celda individuales o los rangos como una sola cadena
        references_and_ranges = re.findall(r'\b[A-Z]{1,3}[0-9]{1,7}(?::[A-Z]{1,3}[0-9]{1,7})?\b', sin_hoja)
        return references_and_ranges

    # Función recursiva para procesar celdas y sus precedentes
    def procesar_celda(celda_actual):
        if celda_actual in visitadas:
            return
        visitadas.add(celda_actual)

        excel_formula = obtener_formula(celda_actual)

        if not excel_formula:
            # Es una celda "raíz" (sin fórmula)
            try:
                # Intenta convertir el valor a float si es numérico, si no, déjalo como está
                valor_raiz = hoja[celda_actual].value
                raices[celda_actual] = float(valor_raiz) if isinstance(valor_raiz, (int, float)) else valor_raiz
            except (ValueError, TypeError):
                raices[celda_actual] = hoja[celda_actual].value
            return

        cleaned_formula = limpiar_formula(excel_formula)
        formulas[celda_actual] = cleaned_formula # Guardamos la fórmula limpia
        
        # Extraer referencias y rangos para procesamiento recursivo
        # Aquí necesitamos todas las celdas involucradas para procesarlas.
        refs_y_rangos = extraer_referencias_y_rangos(excel_formula)
        
        # Expandir los rangos para procesar individualmente cada celda que los compone.
        # Esto es importante para el `procesar_celda` recursivo.
        individual_precedents_for_recursion = set()
        for ref_or_range in refs_y_rangos:
            if ':' in ref_or_range:
                start_ref, end_ref = ref_or_range.split(':')
                # Obtener las coordenadas del rango
                start_col_letter = ''.join(filter(str.isalpha, start_ref))
                start_row = int(''.join(filter(str.isdigit, start_ref)))
                end_col_letter = ''.join(filter(str.isalpha, end_ref))
                end_row = int(''.join(filter(str.isdigit, end_ref)))

                start_col_idx = column_index_from_string(start_col_letter)
                end_col_idx = column_index_from_string(end_col_letter)

                for col_idx in range(start_col_idx, end_col_idx + 1):
                    for row_num in range(start_row, end_row + 1):
                        individual_precedents_for_recursion.add(f"{get_column_letter(col_idx)}{row_num}")
            else:
                individual_precedents_for_recursion.add(ref_or_range)
        
        # Procesar referencias recursivamente
        for ref in individual_precedents_for_recursion:
            procesar_celda(ref)

        # --- Construcción de la expresión Python para `eval()` ---
        python_formula_str = limpiar_formula(excel_formula)
        python_formula_str = re.sub(r"(?:'[^']+'|[A-Za-z0-9_]+)!", "", python_formula_str) # Quitar nombres de hoja
        
        # Primero, manejar funciones que toman rangos (ej. NPV, SUM)
        # Esto es un patrón común para funciones que operan en un conjunto de valores.
        # Definimos una función para reemplazar rangos por listas de llamadas a 'r()'
        def replace_excel_range_with_python_list(match):
            func_name = match.group(1) # Ej: NPV
            args_before_range = match.group(2) # Ej: 0.06,
            range_str = match.group(3) # Ej: G120:V120
            
            start_ref, end_ref = range_str.split(':')
            start_col_letter = ''.join(filter(str.isalpha, start_ref))
            start_row = int(''.join(filter(str.isdigit, start_ref)))
            end_col_letter = ''.join(filter(str.isalpha, end_ref))
            end_row = int(''.join(filter(str.isdigit, end_ref)))

            start_col_idx = column_index_from_string(start_col_letter)
            end_col_idx = column_index_from_string(end_col_letter)

            cells_in_range_list = []
            for col_idx in range(start_col_idx, end_col_idx + 1):
                for row_num in range(start_row, end_row + 1):
                    cells_in_range_list.append(f"r('{get_column_letter(col_idx)}{row_num}')")
            
            # El formato para la función en Python será: FUNCION(arg1, arg2, ..., [r('A1'), r('A2')])
            # Si no hay args_before_range, será solo la lista
            if args_before_range:
                return f"{func_name}({args_before_range.strip()}[{', '.join(cells_in_range_list)}])"
            else:
                return f"{func_name}([{', '.join(cells_in_range_list)}])"

        # Regex para funciones que toman rangos. Ajusta 'NPV|SUM|AVERAGE' a las funciones que uses.
        # Captura: 1. Nombre de la función, 2. Argumentos antes del rango (opcional), 3. El rango
        python_formula_str = re.sub(
            r'([A-Za-z_][A-Za-z0-9_]*)\(([^,)]*,\s*)?([A-Z]{1,3}[0-9]{1,7}:[A-Z]{1,3}[0-9]{1,7})\)',
            replace_excel_range_with_python_list,
            python_formula_str
        )
        
        # Segundo, reemplazar todas las referencias de celda individuales con r('CELDA')
        # Es crucial que esto se haga DESPUÉS de manejar los rangos,
        # para no reemplazar partes de los rangos antes de que se expandan.
        # Usamos el mismo patrón de regex para referencias individuales.
        all_individual_cell_refs = re.findall(r'\b[A-Z]{1,3}[0-9]{1,7}\b', python_formula_str)
        for ref in all_individual_cell_refs:
            # Asegurarse de que no estamos reemplazando partes ya manejadas en los rangos
            # Este es un punto delicado. Un enfoque más seguro es un parser AST.
            # Para la mayoría de los casos simples, esto funcionará.
            python_formula_str = re.sub(rf'\b{ref}\b', f"r('{ref}')", python_formula_str)

        try:
            # Mapear funciones de Excel a funciones Python
            # Aquí puedes agregar más funciones si las necesitas, ej: "ABS": abs, "ROUND": round
            eval_globals = {
                "npv": npv,
                "sum": sum,
                "max": max,
                "min": min,
                "abs": abs,
                # Excel "AND" se mapea a 'and' en Python, "OR" a 'or', pero en 'eval'
                # necesitas que sean funciones si se usan con sintaxis de función.
                # Para un "AND(A1,B1)" necesitarías def AND(a,b): return a and b
                # No soporta IF directamente sin una función IF(cond, val_true, val_false)
                "IF": lambda cond, true_val, false_val: true_val if cond else false_val
            }
            
            # Generar la función lambda para esta celda
            # La lambda toma un argumento 'r', que será una función que obtiene el valor de una celda
            mapa[celda_actual] = eval(f"lambda r: {python_formula_str}", eval_globals)
        except Exception as e:
            print(f"[ERROR] al evaluar fórmula en {celda_actual}: {python_formula_str}")
            print(f"       {e}")

    # Iniciar el procesamiento desde la celda objetivo
    procesar_celda(celda_objetivo)

    return mapa, formulas, raices

# %%
def evaluar_modelo(celda_objetivo, mapa_precedentes, valores_raices, hoja_actual_excel, workbook_excel_obj):
    """
    Evalúa el valor de la celda objetivo utilizando el mapa de precedentes y los valores de las raíces.

    Args:
        celda_objetivo (str): La celda cuyo valor se quiere calcular.
        mapa_precedentes (dict): El diccionario 'mapa' devuelto por generar_precedentes.
        valores_raices (dict): El diccionario 'raices' devuelto por generar_precedentes,
                               que puedes modificar para tu análisis de sensibilidad.
        hoja_actual_excel (str): El nombre de la hoja donde está la celda objetivo (para raíces no mapeadas)
        workbook_excel_obj (openpyxl.workbook.workbook.Workbook): El objeto workbook para leer directamente valores de celdas no mapeadas

    Returns:
        float or object: El valor calculado de la celda objetivo.
    """
    # Caché para almacenar los valores ya calculados de las celdas durante esta evaluación
    # Esto evita recalcular celdas múltiples veces si son precedentes de varias otras.
    cache_valores_calculados = {}
    
    # Esto es importante para manejar celdas que podrían no haber sido incluidas en el mapa
    # si no eran precedentes directos de la celda objetivo, pero podrían ser llamadas por r()
    # (por ejemplo, si el Excel es muy grande y solo extrajiste una rama pequeña).
    # O para obtener valores originales si no están en raices ni en formulas.
    # Es una función de fallback para r()
    def get_excel_cell_value_fallback(cell_ref):
        try:
            return workbook_excel_obj[hoja_actual_excel][cell_ref].value
        except Exception as e:
            print(f"Advertencia: No se pudo obtener el valor de {cell_ref} desde Excel: {e}")
            return None # O lanzar un error si prefieres que sea estricto

    def resolver_valor_celda(ref_celda):
        # 1. ¿Está en el caché de valores calculados?
        if ref_celda in cache_valores_calculados:
            return cache_valores_calculados[ref_celda]

        # 2. ¿Es una celda raíz (valor fijo)?
        if ref_celda in valores_raices:
            # Los valores de las raíces son la fuente de verdad inicial y las que variarás
            valor = valores_raices[ref_celda]
            cache_valores_calculados[ref_celda] = valor
            return valor

        # 3. ¿Es una celda con fórmula en nuestro mapa?
        if ref_celda in mapa_precedentes:
            # Si es una fórmula, la evaluamos recursivamente
            # La lambda toma 'resolver_valor_celda' como su 'r'
            valor = mapa_precedentes[ref_celda](resolver_valor_celda)
            cache_valores_calculados[ref_celda] = valor
            return valor
        
        # 4. Si no está en raíces ni en el mapa, intenta leer directamente del Excel original
        # Esto es un fallback importante para celdas no procesadas que puedan ser requeridas.
        valor = get_excel_cell_value_fallback(ref_celda)
        if isinstance(valor, (int, float)):
             cache_valores_calculados[ref_celda] = valor
             return valor
        
        # Si la celda no tiene valor numérico, podría ser texto o un error, lo cual causaría problemas.
        # Puedes decidir cómo manejar esto (ej. devolver 0, None, o lanzar un error)
        print(f"Advertencia: Celda {ref_celda} no es raíz, no tiene fórmula ni valor numérico directo. Su valor es: {valor}")
        return valor # Retorna el valor tal cual, puede ser None o str

    return resolver_valor_celda(celda_objetivo)

# %%
ruta_excel = "/Users/alvarofelipepupuchemorales/Desktop/Proyecto Economia/assets/PALTA HASS  BCP.xlsx"
hoja_nombre = "Costos Agricolas 01 ha"
celda_objetivo = "E123"

# %%
# --- Ejemplo de uso ---
if __name__ == "__main__":
    # Asegúrate de tener un archivo Excel de prueba, por ejemplo, 'mi_modelo.xlsx'
    # Con una hoja 'Hoja1' y algunas fórmulas.
    # Ejemplo:
    # A1: 100 (Raíz)
    # A2: 1.05 (Raíz)
    # B1: =A1 * A2 (Fórmula)
    # B2: =B1 + 50 (Fórmula)
    # C1: =NPV(0.05, A1:A3) (Fórmula con rango - necesitarás A3)
    # A3: 200 (Raíz para NPV)
    # D1: =+A1*B1 (Fórmula con +)
    # D2: =1*A1 (Fórmula con 1*)
    # E1: =IF(A1>50, B1, A2)

    ruta = ruta_excel # ¡CAMBIA ESTO!
    hoja_obj = hoja_nombre # ¡CAMBIA ESTO!
    celda_obj = celda_objetivo   # ¡CAMBIA ESTO a tu celda final!

    # --- Preparación: Generar el mapa ---
    # Necesitas el objeto workbook completo para el fallback en evaluar_modelo
    wb_full = openpyxl.load_workbook(ruta, data_only=False)
    
    print(f"Generando mapa de precedentes para {celda_obj}...")
    mapa_precedentes, formulas_extraidas, raices_originales = generar_precedentes(ruta, hoja_obj, celda_obj)
    
    print("\n--- Fórmulas Extraídas ---")
    for celda, formula_py in mapa_precedentes.items():
        print(f"Celda: {celda}, Fórmula Excel: {formulas_extraidas.get(celda, 'N/A')}, Función Python: {formula_py}")
    
    print("\n--- Raíces Originales ---")
    for celda, valor in raices_originales.items():
        print(f"Celda: {celda}, Valor: {valor}")

    # --- Análisis de Sensibilidad ---
    print(f"\n--- Iniciando Análisis de Sensibilidad para {celda_obj} ---")

    # 1. Calcular el valor base de la celda objetivo
    valor_base_objetivo = evaluar_modelo(celda_obj, mapa_precedentes, raices_originales.copy(), hoja_obj, wb_full)
    print(f"\nValor base de {celda_obj}: {valor_base_objetivo}")

    resultados_sensibilidad = {}
# Out:
# Generando mapa de precedentes para E123...
# [ERROR] al evaluar fórmula en J95: r('J94')*$H$95
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en K95: r('K94')*$H$95
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en L95: r('L94')*$H$95
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en M95: r('M94')*$H$95
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en N95: r('N94')*$H$95
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en O95: r('O94')*$H$95
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en P95: r('P94')*$H$95
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en M45: 1*$E$45
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en M48: r('M45')*$E$48
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en M55: r('M48')*$E$55
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en M46: r('M45')*$E$46
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en M53: r('M46')*$E$53
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en R45: 1*$E$45
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en R48: r('R45')*$E$48
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en R55: r('R48')*$E$55
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en R46: r('R45')*$E$46
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en R53: r('R46')*$E$53
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en I48: r('I45')*$E$48
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en I55: r('I48')*$E$55
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en I46: r('I45')*$E$46
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en I53: r('I46')*$E$53
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en P45: 1*$E$45
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en P48: r('P45')*$E$48
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en P55: r('P48')*$E$55
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en P46: r('P45')*$E$46
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en P53: r('P46')*$E$53
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en Q95: r('Q94')*$H$95
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en R95: r('R94')*$H$95
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en S95: r('S94')*$H$95
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en K46: r('K45')*$E$46
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en K53: r('K46')*$E$53
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en K48: r('K45')*$E$48
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en K55: r('K48')*$E$55
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en L48: r('L45')*$E$48
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en L55: r('L48')*$E$55
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en L46: r('L45')*$E$46
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en L53: r('L46')*$E$53
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en U45: 1*$E$45
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en U46: r('U45')*$E$46
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en U53: r('U46')*$E$53
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en U48: r('U45')*$E$48
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en U55: r('U48')*$E$55
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en T45: 1*$E$45
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en T46: r('T45')*$E$46
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en T53: r('T46')*$E$53
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en T48: r('T45')*$E$48
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en T55: r('T48')*$E$55
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en N45: 1*$E$45
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en N48: r('N45')*$E$48
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en N55: r('N48')*$E$55
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en N46: r('N45')*$E$46
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en N53: r('N46')*$E$53
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en Q45: 1*$E$45
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en Q46: r('Q45')*$E$46
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en Q53: r('Q46')*$E$53
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en Q48: r('Q45')*$E$48
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en Q55: r('Q48')*$E$55
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en J48: r('J45')*$E$48
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en J55: r('J48')*$E$55
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en J46: r('J45')*$E$46
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en J53: r('J46')*$E$53
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en H48: r('H45')*$E$48
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en H55: r('H48')*$E$55
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en H46: r('H45')*$E$46
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en H53: r('H46')*$E$53
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en O45: 1*$E$45
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en O46: r('O45')*$E$46
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en O53: r('O46')*$E$53
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en O48: r('O45')*$E$48
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en O55: r('O48')*$E$55
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en S45: 1*$E$45
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en S48: r('S45')*$E$48
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en S55: r('S48')*$E$55
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en S46: r('S45')*$E$46
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en S53: r('S46')*$E$53
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en V45: 1*$E$45
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en V48: r('V45')*$E$48
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en V55: r('V48')*$E$55
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en V46: r('V45')*$E$46
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en V53: r('V46')*$E$53
#        invalid syntax (<string>, line 1)
# [ERROR] al evaluar fórmula en E123: NPV(0.06,[r('r('G120')'), r('r('H120')'), r('r('I120')'), r('r('J120')'), r('r('K120')'), r('r('L120')'), r('r('M120')'), r('r('N120')'), r('r('O120')'), r('r('P120')'), r('r('Q120')'), r('r('R120')'), r('r('S120')'), r('r('T120')'), r('r('U120')'), r('r('V120')')])+r('E120')+r('F120')
#        invalid syntax. Perhaps you forgot a comma? (<string>, line 1)
#
# --- Fórmulas Extraídas ---
# Celda: M26, Fórmula Excel: 20000*0.075, Función Python: <function <lambda> at 0x118a66440>
# Celda: M11, Fórmula Excel: M16+M17+M19+M23+M24+M26+M15+M25, Función Python: <function <lambda> at 0x118a66710>
# Celda: M38, Fórmula Excel: M11*0.03, Función Python: <function <lambda> at 0x118a67400>
# Celda: M39, Fórmula Excel: M11*0.03, Función Python: <function <lambda> at 0x118a660e0>
# Celda: M36, Fórmula Excel: M38+M39+M37, Función Python: <function <lambda> at 0x118ad79a0>
# Celda: M41, Fórmula Excel: M11+M36, Función Python: <function <lambda> at 0x118ad6a70>
# Celda: M81, Fórmula Excel: 'Costos Agricolas 01 ha'!M41, Función Python: <function <lambda> at 0x118ad6b00>
# Celda: M82, Fórmula Excel: 30000/16, Función Python: <function <lambda> at 0x118ad6290>
# Celda: J97, Fórmula Excel: PMT(H95,10,-F98), Función Python: <function <lambda> at 0x118ad6ef0>
# Celda: K97, Fórmula Excel: J97, Función Python: <function <lambda> at 0x118ad6950>
# Celda: L97, Fórmula Excel: K97, Función Python: <function <lambda> at 0x118ad7f40>
# Celda: J96, Fórmula Excel: J97-J95, Función Python: <function <lambda> at 0x118ad64d0>
# Celda: K94, Fórmula Excel: J94-J96, Función Python: <function <lambda> at 0x118ad6d40>
# Celda: K96, Fórmula Excel: K97-K95, Función Python: <function <lambda> at 0x118ad6680>
# Celda: L94, Fórmula Excel: K94-K96, Función Python: <function <lambda> at 0x118ad6560>
# Celda: L96, Fórmula Excel: L97-L95, Función Python: <function <lambda> at 0x118ad6dd0>
# Celda: M94, Fórmula Excel: L94-L96, Función Python: <function <lambda> at 0x118ad65f0>
# Celda: M97, Fórmula Excel: L97, Función Python: <function <lambda> at 0x118ad7130>
# Celda: M96, Fórmula Excel: M97-M95, Función Python: <function <lambda> at 0x118ad72e0>
# Celda: N94, Fórmula Excel: M94-M96, Función Python: <function <lambda> at 0x118ad7e20>
# Celda: N97, Fórmula Excel: M97, Función Python: <function <lambda> at 0x118ad7b50>
# Celda: N96, Fórmula Excel: N97-N95, Función Python: <function <lambda> at 0x118ad7be0>
# Celda: O94, Fórmula Excel: N94-N96, Función Python: <function <lambda> at 0x118ad7c70>
# Celda: O97, Fórmula Excel: N97, Función Python: <function <lambda> at 0x118ad7eb0>
# Celda: O96, Fórmula Excel: O97-O95, Función Python: <function <lambda> at 0x118ad7ac0>
# Celda: P94, Fórmula Excel: O94-O96, Función Python: <function <lambda> at 0x1193b0af0>
# Celda: M83, Fórmula Excel: P95, Función Python: <function <lambda> at 0x1193b0310>
# Celda: M58, Fórmula Excel: M53+M55, Función Python: <function <lambda> at 0x1193b0820>
# Celda: M57, Fórmula Excel: M58, Función Python: <function <lambda> at 0x1193b0430>
# Celda: M80, Fórmula Excel: 'Costos Agricolas 01 ha'!M57, Función Python: <function <lambda> at 0x1193b0b80>
# Celda: M84, Fórmula Excel: M80-M81-M82-M83, Función Python: <function <lambda> at 0x1193b0940>
# Celda: M85, Fórmula Excel: M84*0.15, Función Python: <function <lambda> at 0x1193b00d0>
# Celda: P97, Fórmula Excel: O97, Función Python: <function <lambda> at 0x1193b08b0>
# Celda: P96, Fórmula Excel: P97-P95, Función Python: <function <lambda> at 0x1193b0a60>
# Celda: M86, Fórmula Excel: P96, Función Python: <function <lambda> at 0x1193b0ca0>
# Celda: M89, Fórmula Excel: M84-M85-M86-M87+M88, Función Python: <function <lambda> at 0x1193b0d30>
# Celda: M120, Fórmula Excel: M89*16.52, Función Python: <function <lambda> at 0x1193b0ee0>
# Celda: R82, Fórmula Excel: 30000/16, Función Python: <function <lambda> at 0x1193b0f70>
# Celda: R58, Fórmula Excel: R53+R55, Función Python: <function <lambda> at 0x1193b1090>
# Celda: R57, Fórmula Excel: R58, Función Python: <function <lambda> at 0x1193b11b0>
# Celda: R80, Fórmula Excel: 'Costos Agricolas 01 ha'!R57, Función Python: <function <lambda> at 0x1193b12d0>
# Celda: R26, Fórmula Excel: 20000*0.075, Función Python: <function <lambda> at 0x1193b13f0>
# Celda: R11, Fórmula Excel: R16+R17+R19+R23+R24+R26+R15+R25, Función Python: <function <lambda> at 0x1193b15a0>
# Celda: R39, Fórmula Excel: R11*0.03, Función Python: <function <lambda> at 0x1193b1630>
# Celda: R38, Fórmula Excel: R11*0.03, Función Python: <function <lambda> at 0x1193b1750>
# Celda: R36, Fórmula Excel: R38+R39+R37, Función Python: <function <lambda> at 0x1193b1870>
# Celda: R41, Fórmula Excel: R11+R36, Función Python: <function <lambda> at 0x1193b1990>
# Celda: R81, Fórmula Excel: 'Costos Agricolas 01 ha'!R41, Función Python: <function <lambda> at 0x1193b1ab0>
# Celda: R84, Fórmula Excel: R80-R81-R82-R83, Función Python: <function <lambda> at 0x1193b1bd0>
# Celda: R85, Fórmula Excel: R84*0.15, Función Python: <function <lambda> at 0x1193b1cf0>
# Celda: R89, Fórmula Excel: R84-R85-R86-R87+R88, Función Python: <function <lambda> at 0x1193b1e10>
# Celda: R120, Fórmula Excel: R89*16.52, Función Python: <function <lambda> at 0x1193b1f30>
# Celda: I83, Fórmula Excel: L95, Función Python: <function <lambda> at 0x1193b2050>
# Celda: I26, Fórmula Excel: 12000*0.075, Función Python: <function <lambda> at 0x1193b2170>
# Celda: I11, Fórmula Excel: I16+I17+I19+I23+I24+I26+I15+I25, Función Python: <function <lambda> at 0x1193b2320>
# Celda: I39, Fórmula Excel: I11*0.03, Función Python: <function <lambda> at 0x1193b23b0>
# Celda: I38, Fórmula Excel: I11*0.03, Función Python: <function <lambda> at 0x1193b24d0>
# Celda: I36, Fórmula Excel: I38+I39+I37, Función Python: <function <lambda> at 0x1193b25f0>
# Celda: I41, Fórmula Excel: I11+I36, Función Python: <function <lambda> at 0x1193b2710>
# Celda: I81, Fórmula Excel: 'Costos Agricolas 01 ha'!I41, Función Python: <function <lambda> at 0x1193b2830>
# Celda: I82, Fórmula Excel: 30000/16, Función Python: <function <lambda> at 0x1193b2950>
# Celda: I45, Fórmula Excel: 0.48*E45, Función Python: <function <lambda> at 0x1193b2a70>
# Celda: I58, Fórmula Excel: I53+I55, Función Python: <function <lambda> at 0x1193b2b90>
# Celda: I57, Fórmula Excel: I58, Función Python: <function <lambda> at 0x1193b2cb0>
# Celda: I80, Fórmula Excel: 'Costos Agricolas 01 ha'!I57, Función Python: <function <lambda> at 0x1193b2dd0>
# Celda: I84, Fórmula Excel: I80-I81-I82-I83, Función Python: <function <lambda> at 0x1193b2ef0>
# Celda: I86, Fórmula Excel: L96, Función Python: <function <lambda> at 0x1193b3010>
# Celda: I89, Fórmula Excel: I84-I85-I86-I87+I88, Función Python: <function <lambda> at 0x1193b3130>
# Celda: I120, Fórmula Excel: I89*16.52, Función Python: <function <lambda> at 0x1193b3250>
# Celda: G80, Fórmula Excel: 'Costos Agricolas 01 ha'!G57, Función Python: <function <lambda> at 0x1193b3370>
# Celda: G83, Fórmula Excel: J95, Función Python: <function <lambda> at 0x1193b3490>
# Celda: G82, Fórmula Excel: 30000/16, Función Python: <function <lambda> at 0x1193b35b0>
# Celda: G26, Fórmula Excel: 9000*0.075, Función Python: <function <lambda> at 0x1193b36d0>
# Celda: G11, Fórmula Excel: G16+G17+G19+G23+G24+G26+G15+G25, Función Python: <function <lambda> at 0x1193b3880>
# Celda: G39, Fórmula Excel: G11*0.03, Función Python: <function <lambda> at 0x1193b3910>
# Celda: G38, Fórmula Excel: G11*0.03, Función Python: <function <lambda> at 0x1193b3a30>
# Celda: G36, Fórmula Excel: G38+G39+G37, Función Python: <function <lambda> at 0x1193b3b50>
# Celda: G41, Fórmula Excel: G11+G36, Función Python: <function <lambda> at 0x1193b3c70>
# Celda: G81, Fórmula Excel: 'Costos Agricolas 01 ha'!G41, Función Python: <function <lambda> at 0x1193b3d90>
# Celda: G84, Fórmula Excel: G80-G81-G82-G83, Función Python: <function <lambda> at 0x1193b3eb0>
# Celda: G86, Fórmula Excel: J96, Función Python: <function <lambda> at 0x118d08040>
# Celda: G89, Fórmula Excel: G84-G85-G86-G87+G88, Función Python: <function <lambda> at 0x118d08160>
# Celda: G120, Fórmula Excel: G89*16.52, Función Python: <function <lambda> at 0x118d08280>
# Celda: P82, Fórmula Excel: 30000/16, Función Python: <function <lambda> at 0x118d083a0>
# Celda: P58, Fórmula Excel: P53+P55, Función Python: <function <lambda> at 0x118d084c0>
# Celda: P57, Fórmula Excel: P58, Función Python: <function <lambda> at 0x118d085e0>
# Celda: P80, Fórmula Excel: 'Costos Agricolas 01 ha'!P57, Función Python: <function <lambda> at 0x118d08700>
# Celda: Q94, Fórmula Excel: P94-P96, Función Python: <function <lambda> at 0x118d08820>
# Celda: Q97, Fórmula Excel: P97, Función Python: <function <lambda> at 0x118d08940>
# Celda: Q96, Fórmula Excel: Q97-Q95, Función Python: <function <lambda> at 0x118d08a60>
# Celda: R94, Fórmula Excel: Q94-Q96, Función Python: <function <lambda> at 0x118d08b80>
# Celda: R97, Fórmula Excel: Q97, Función Python: <function <lambda> at 0x118d08ca0>
# Celda: R96, Fórmula Excel: R97-R95, Función Python: <function <lambda> at 0x118d08dc0>
# Celda: S94, Fórmula Excel: R94-R96, Función Python: <function <lambda> at 0x118d08ee0>
# Celda: P83, Fórmula Excel: S95, Función Python: <function <lambda> at 0x118d09000>
# Celda: P26, Fórmula Excel: 20000*0.075, Función Python: <function <lambda> at 0x118d09120>
# Celda: P11, Fórmula Excel: P16+P17+P19+P23+P24+P26+P15+P25, Función Python: <function <lambda> at 0x118d092d0>
# Celda: P39, Fórmula Excel: P11*0.03, Función Python: <function <lambda> at 0x118d09360>
# Celda: P38, Fórmula Excel: P11*0.03, Función Python: <function <lambda> at 0x118d09480>
# Celda: P36, Fórmula Excel: P38+P39+P37, Función Python: <function <lambda> at 0x118d095a0>
# Celda: P41, Fórmula Excel: P11+P36, Función Python: <function <lambda> at 0x118d096c0>
# Celda: P81, Fórmula Excel: 'Costos Agricolas 01 ha'!P41, Función Python: <function <lambda> at 0x118d097e0>
# Celda: P84, Fórmula Excel: P80-P81-P82-P83, Función Python: <function <lambda> at 0x118d09900>
# Celda: S97, Fórmula Excel: R97, Función Python: <function <lambda> at 0x118d09a20>
# Celda: S96, Fórmula Excel: S97-S95, Función Python: <function <lambda> at 0x118d09b40>
# Celda: P86, Fórmula Excel: S96, Función Python: <function <lambda> at 0x118d09c60>
# Celda: P85, Fórmula Excel: P84*0.15, Función Python: <function <lambda> at 0x118d09d80>
# Celda: P89, Fórmula Excel: P84-P85-P86-P87+P88, Función Python: <function <lambda> at 0x118d09ea0>
# Celda: P120, Fórmula Excel: P89*16.52, Función Python: <function <lambda> at 0x118d09fc0>
# Celda: K82, Fórmula Excel: 30000/16, Función Python: <function <lambda> at 0x118d0a0e0>
# Celda: K83, Fórmula Excel: N95, Función Python: <function <lambda> at 0x118d0a200>
# Celda: K26, Fórmula Excel: 20000*0.075, Función Python: <function <lambda> at 0x118d0a320>
# Celda: K11, Fórmula Excel: K16+K17+K19+K23+K24+K26+K15+K25, Función Python: <function <lambda> at 0x118d0a4d0>
# Celda: K38, Fórmula Excel: K11*0.03, Función Python: <function <lambda> at 0x118d0a560>
# Celda: K39, Fórmula Excel: K11*0.03, Función Python: <function <lambda> at 0x118d0a680>
# Celda: K36, Fórmula Excel: K38+K39+K37, Función Python: <function <lambda> at 0x118d0a7a0>
# Celda: K41, Fórmula Excel: K11+K36, Función Python: <function <lambda> at 0x118d0a8c0>
# Celda: K81, Fórmula Excel: 'Costos Agricolas 01 ha'!K41, Función Python: <function <lambda> at 0x118d0a9e0>
# Celda: K45, Fórmula Excel: 0.76*E45, Función Python: <function <lambda> at 0x118d0ab00>
# Celda: K58, Fórmula Excel: K53+K55, Función Python: <function <lambda> at 0x118d0ac20>
# Celda: K57, Fórmula Excel: K58, Función Python: <function <lambda> at 0x118d0ad40>
# Celda: K80, Fórmula Excel: 'Costos Agricolas 01 ha'!K57, Función Python: <function <lambda> at 0x118d0ae60>
# Celda: K84, Fórmula Excel: K80-K81-K82-K83, Función Python: <function <lambda> at 0x118d0af80>
# Celda: K85, Fórmula Excel: K84*0.15, Función Python: <function <lambda> at 0x118d0b0a0>
# Celda: K86, Fórmula Excel: N96, Función Python: <function <lambda> at 0x118d0b1c0>
# Celda: K89, Fórmula Excel: K84-K85-K86-K87+K88, Función Python: <function <lambda> at 0x118d0b2e0>
# Celda: K120, Fórmula Excel: K89*16.52, Función Python: <function <lambda> at 0x118d0b400>
# Celda: L83, Fórmula Excel: O95, Función Python: <function <lambda> at 0x118d0b520>
# Celda: L45, Fórmula Excel: 0.92*E45, Función Python: <function <lambda> at 0x118d0b640>
# Celda: L58, Fórmula Excel: L53+L55, Función Python: <function <lambda> at 0x118d0b760>
# Celda: L57, Fórmula Excel: L58, Función Python: <function <lambda> at 0x118d0b880>
# Celda: L80, Fórmula Excel: 'Costos Agricolas 01 ha'!L57, Función Python: <function <lambda> at 0x118d0b9a0>
# Celda: L26, Fórmula Excel: 20000*0.075, Función Python: <function <lambda> at 0x118d0bac0>
# Celda: L11, Fórmula Excel: L16+L17+L19+L23+L24+L26+L15+L25, Función Python: <function <lambda> at 0x118d0bc70>
# Celda: L39, Fórmula Excel: L11*0.03, Función Python: <function <lambda> at 0x118d0bd00>
# Celda: L38, Fórmula Excel: L11*0.03, Función Python: <function <lambda> at 0x118d0be20>
# Celda: L36, Fórmula Excel: L38+L39+L37, Función Python: <function <lambda> at 0x118d0bf40>
# Celda: L41, Fórmula Excel: L11+L36, Función Python: <function <lambda> at 0x1193440d0>
# Celda: L81, Fórmula Excel: 'Costos Agricolas 01 ha'!L41, Función Python: <function <lambda> at 0x1193441f0>
# Celda: L82, Fórmula Excel: 30000/16, Función Python: <function <lambda> at 0x119344310>
# Celda: L84, Fórmula Excel: L80-L81-L82-L83, Función Python: <function <lambda> at 0x119344430>
# Celda: L86, Fórmula Excel: O96, Función Python: <function <lambda> at 0x119344550>
# Celda: L85, Fórmula Excel: L84*0.15, Función Python: <function <lambda> at 0x119344670>
# Celda: L89, Fórmula Excel: L84-L85-L86-L87+L88, Función Python: <function <lambda> at 0x119344790>
# Celda: L120, Fórmula Excel: L89*16.52, Función Python: <function <lambda> at 0x1193448b0>
# Celda: U82, Fórmula Excel: 30000/16, Función Python: <function <lambda> at 0x1193449d0>
# Celda: U26, Fórmula Excel: 20000*0.075, Función Python: <function <lambda> at 0x119344af0>
# Celda: U11, Fórmula Excel: U16+U17+U19+U23+U24+U26+U15+U25, Función Python: <function <lambda> at 0x119344ca0>
# Celda: U39, Fórmula Excel: U11*0.03, Función Python: <function <lambda> at 0x119344d30>
# Celda: U38, Fórmula Excel: U11*0.03, Función Python: <function <lambda> at 0x119344e50>
# Celda: U36, Fórmula Excel: U38+U39+U37, Función Python: <function <lambda> at 0x119344f70>
# Celda: U41, Fórmula Excel: U11+U36, Función Python: <function <lambda> at 0x119345090>
# Celda: U81, Fórmula Excel: 'Costos Agricolas 01 ha'!U41, Función Python: <function <lambda> at 0x1193451b0>
# Celda: U58, Fórmula Excel: U53+U55, Función Python: <function <lambda> at 0x1193452d0>
# Celda: U57, Fórmula Excel: U58, Función Python: <function <lambda> at 0x1193453f0>
# Celda: U80, Fórmula Excel: 'Costos Agricolas 01 ha'!U57, Función Python: <function <lambda> at 0x119345510>
# Celda: U84, Fórmula Excel: U80-U81-U82-U83, Función Python: <function <lambda> at 0x119345630>
# Celda: U85, Fórmula Excel: U84*0.15, Función Python: <function <lambda> at 0x119345750>
# Celda: U89, Fórmula Excel: U84-U85-U86-U87+U88, Función Python: <function <lambda> at 0x119345870>
# Celda: U120, Fórmula Excel: U89*16.52, Función Python: <function <lambda> at 0x119345990>
# Celda: E88, Fórmula Excel: 'PALTA HASS activos'!H52+'PALTA HASS activos'!H22+'PALTA HASS activos'!G34, Función Python: <function <lambda> at 0x119345ab0>
# Celda: H26, Fórmula Excel: 9000*0.075, Función Python: <function <lambda> at 0x119345bd0>
# Celda: H11, Fórmula Excel: H16+H17+H19+H23+H24+H26+H15+H25, Función Python: <function <lambda> at 0x119345d80>
# Celda: H38, Fórmula Excel: H11*0.03, Función Python: <function <lambda> at 0x119345e10>
# Celda: H39, Fórmula Excel: H11*0.03, Función Python: <function <lambda> at 0x119345f30>
# Celda: H36, Fórmula Excel: H38+H39+H37, Función Python: <function <lambda> at 0x119346050>
# Celda: E32, Fórmula Excel: 'PALTA HASS activos'!H36, Función Python: <function <lambda> at 0x119346170>
# Celda: E33, Fórmula Excel: 'PALTA HASS activos'!H52, Función Python: <function <lambda> at 0x119346290>
# Celda: E34, Fórmula Excel: 'PALTA HASS activos'!H45, Función Python: <function <lambda> at 0x1193463b0>
# Celda: E30, Fórmula Excel: 'PALTA HASS activos'!H26, Función Python: <function <lambda> at 0x1193464d0>
# Celda: E31, Fórmula Excel: 'PALTA HASS activos'!G34, Función Python: <function <lambda> at 0x1193465f0>
# Celda: E11, Fórmula Excel: E29+E30+E31+E32+E33+E34, Función Python: <function <lambda> at 0x119346710>
# Celda: E41, Fórmula Excel: E11, Función Python: <function <lambda> at 0x119346830>
# Celda: E87, Fórmula Excel: 'Costos Agricolas 01 ha'!E41, Función Python: <function <lambda> at 0x119346950>
# Celda: E89, Fórmula Excel: E84-E85-E86-E87+E88, Función Python: <function <lambda> at 0x119346a70>
# Celda: E120, Fórmula Excel: E89*16.52, Función Python: <function <lambda> at 0x119346b90>
# Celda: F31, Fórmula Excel: 'INSTALACION Y SIEMBRA'!B23, Función Python: <function <lambda> at 0x119346cb0>
# Celda: F23, Fórmula Excel: 'INSTALACION Y SIEMBRA'!B28, Función Python: <function <lambda> at 0x119346dd0>
# Celda: F15, Fórmula Excel: 'INSTALACION Y SIEMBRA'!B19, Función Python: <function <lambda> at 0x119346ef0>
# Celda: F22, Fórmula Excel: 'INSTALACION Y SIEMBRA'!B26, Función Python: <function <lambda> at 0x119347010>
# Celda: F11, Fórmula Excel: F15+F22+F23+F31, Función Python: <function <lambda> at 0x119347130>
# Celda: F41, Fórmula Excel: F11, Función Python: <function <lambda> at 0x119347250>
# Celda: F87, Fórmula Excel: 'Costos Agricolas 01 ha'!F41, Función Python: <function <lambda> at 0x119347370>
# Celda: F89, Fórmula Excel: F84-F85-F86-F87+F88, Función Python: <function <lambda> at 0x119347490>
# Celda: F120, Fórmula Excel: F89*16.52, Función Python: <function <lambda> at 0x1193475b0>
# Celda: T26, Fórmula Excel: 20000*0.075, Función Python: <function <lambda> at 0x1193476d0>
# Celda: T11, Fórmula Excel: T16+T17+T19+T23+T24+T26+T15+T25, Función Python: <function <lambda> at 0x119347880>
# Celda: T39, Fórmula Excel: T11*0.03, Función Python: <function <lambda> at 0x119347910>
# Celda: T38, Fórmula Excel: T11*0.03, Función Python: <function <lambda> at 0x119347a30>
# Celda: T36, Fórmula Excel: T38+T39+T37, Función Python: <function <lambda> at 0x119347b50>
# Celda: T41, Fórmula Excel: T11+T36, Función Python: <function <lambda> at 0x119347c70>
# Celda: T81, Fórmula Excel: 'Costos Agricolas 01 ha'!T41, Función Python: <function <lambda> at 0x119347d90>
# Celda: T82, Fórmula Excel: 30000/16, Función Python: <function <lambda> at 0x119347eb0>
# Celda: T58, Fórmula Excel: T53+T55, Función Python: <function <lambda> at 0x119340040>
# Celda: T57, Fórmula Excel: T58, Función Python: <function <lambda> at 0x119340160>
# Celda: T80, Fórmula Excel: 'Costos Agricolas 01 ha'!T57, Función Python: <function <lambda> at 0x119340280>
# Celda: T84, Fórmula Excel: T80-T81-T82-T83, Función Python: <function <lambda> at 0x1193403a0>
# Celda: T85, Fórmula Excel: T84*0.15, Función Python: <function <lambda> at 0x1193404c0>
# Celda: T89, Fórmula Excel: T84-T85-T86-T87+T88, Función Python: <function <lambda> at 0x1193405e0>
# Celda: T120, Fórmula Excel: T89*16.52, Función Python: <function <lambda> at 0x119340700>
# Celda: N86, Fórmula Excel: Q96, Función Python: <function <lambda> at 0x119340820>
# Celda: N83, Fórmula Excel: Q95, Función Python: <function <lambda> at 0x119340940>
# Celda: N26, Fórmula Excel: 20000*0.075, Función Python: <function <lambda> at 0x119340a60>
# Celda: N11, Fórmula Excel: N16+N17+N19+N23+N24+N26+N15+N25, Función Python: <function <lambda> at 0x119340c10>
# Celda: N38, Fórmula Excel: N11*0.03, Función Python: <function <lambda> at 0x119340ca0>
# Celda: N39, Fórmula Excel: N11*0.03, Función Python: <function <lambda> at 0x119340dc0>
# Celda: N36, Fórmula Excel: N38+N39+N37, Función Python: <function <lambda> at 0x119340ee0>
# Celda: N41, Fórmula Excel: N11+N36, Función Python: <function <lambda> at 0x119341000>
# Celda: N81, Fórmula Excel: 'Costos Agricolas 01 ha'!N41, Función Python: <function <lambda> at 0x119341120>
# Celda: N58, Fórmula Excel: N53+N55, Función Python: <function <lambda> at 0x119341240>
# Celda: N57, Fórmula Excel: N58, Función Python: <function <lambda> at 0x119341360>
# Celda: N80, Fórmula Excel: 'Costos Agricolas 01 ha'!N57, Función Python: <function <lambda> at 0x119341480>
# Celda: N82, Fórmula Excel: 30000/16, Función Python: <function <lambda> at 0x1193415a0>
# Celda: N84, Fórmula Excel: N80-N81-N82-N83, Función Python: <function <lambda> at 0x1193416c0>
# Celda: N85, Fórmula Excel: N84*0.15, Función Python: <function <lambda> at 0x1193417e0>
# Celda: N89, Fórmula Excel: N84-N85-N86-N87+N88, Función Python: <function <lambda> at 0x119341900>
# Celda: N120, Fórmula Excel: N89*16.52, Función Python: <function <lambda> at 0x119341a20>
# Celda: Q82, Fórmula Excel: 30000/16, Función Python: <function <lambda> at 0x119341b40>
# Celda: Q26, Fórmula Excel: 20000*0.075, Función Python: <function <lambda> at 0x119341c60>
# Celda: Q11, Fórmula Excel: Q16+Q17+Q19+Q23+Q24+Q26+Q15+Q25, Función Python: <function <lambda> at 0x119341e10>
# Celda: Q39, Fórmula Excel: Q11*0.03, Función Python: <function <lambda> at 0x119341ea0>
# Celda: Q38, Fórmula Excel: Q11*0.03, Función Python: <function <lambda> at 0x119341fc0>
# Celda: Q36, Fórmula Excel: Q38+Q39+Q37, Función Python: <function <lambda> at 0x1193420e0>
# Celda: Q41, Fórmula Excel: Q11+Q36, Función Python: <function <lambda> at 0x119342200>
# Celda: Q81, Fórmula Excel: 'Costos Agricolas 01 ha'!Q41, Función Python: <function <lambda> at 0x119342320>
# Celda: Q58, Fórmula Excel: Q53+Q55, Función Python: <function <lambda> at 0x119342440>
# Celda: Q57, Fórmula Excel: Q58, Función Python: <function <lambda> at 0x119342560>
# Celda: Q80, Fórmula Excel: 'Costos Agricolas 01 ha'!Q57, Función Python: <function <lambda> at 0x119342680>
# Celda: Q84, Fórmula Excel: Q80-Q81-Q82-Q83, Función Python: <function <lambda> at 0x1193427a0>
# Celda: Q85, Fórmula Excel: Q84*0.15, Función Python: <function <lambda> at 0x1193428c0>
# Celda: Q89, Fórmula Excel: Q84-Q85-Q86-Q87+Q88, Función Python: <function <lambda> at 0x1193429e0>
# Celda: Q120, Fórmula Excel: Q89*16.52, Función Python: <function <lambda> at 0x119342b00>
# Celda: J86, Fórmula Excel: M96, Función Python: <function <lambda> at 0x119342c20>
# Celda: J83, Fórmula Excel: M95, Función Python: <function <lambda> at 0x119342d40>
# Celda: J26, Fórmula Excel: 18000*0.075, Función Python: <function <lambda> at 0x119342e60>
# Celda: J11, Fórmula Excel: J16+J17+J19+J23+J24+J26+J15+J25, Función Python: <function <lambda> at 0x119343010>
# Celda: J39, Fórmula Excel: J11*0.03, Función Python: <function <lambda> at 0x1193430a0>
# Celda: J38, Fórmula Excel: J11*0.03, Función Python: <function <lambda> at 0x1193431c0>
# Celda: J36, Fórmula Excel: J38+J39+J37, Función Python: <function <lambda> at 0x1193432e0>
# Celda: J41, Fórmula Excel: J11+J36, Función Python: <function <lambda> at 0x119343400>
# Celda: J81, Fórmula Excel: 'Costos Agricolas 01 ha'!J41, Función Python: <function <lambda> at 0x119343520>
# Celda: J45, Fórmula Excel: 0.64*E45, Función Python: <function <lambda> at 0x119343640>
# Celda: J58, Fórmula Excel: J53+J55, Función Python: <function <lambda> at 0x119343760>
# Celda: J57, Fórmula Excel: J58, Función Python: <function <lambda> at 0x119343880>
# Celda: J80, Fórmula Excel: 'Costos Agricolas 01 ha'!J57, Función Python: <function <lambda> at 0x1193439a0>
# Celda: J82, Fórmula Excel: 30000/16, Función Python: <function <lambda> at 0x119343ac0>
# Celda: J84, Fórmula Excel: J80-J81-J82-J83, Función Python: <function <lambda> at 0x119343be0>
# Celda: H41, Fórmula Excel: H11+H36, Función Python: <function <lambda> at 0x119343d00>
# Celda: H81, Fórmula Excel: 'Costos Agricolas 01 ha'!H41, Función Python: <function <lambda> at 0x119343e20>
# Celda: H58, Fórmula Excel: H53+H55, Función Python: <function <lambda> at 0x119343f40>
# Celda: H57, Fórmula Excel: H58, Función Python: <function <lambda> at 0x118a980d0>
# Celda: H80, Fórmula Excel: 'Costos Agricolas 01 ha'!H57, Función Python: <function <lambda> at 0x118a981f0>
# Celda: H83, Fórmula Excel: K95, Función Python: <function <lambda> at 0x118a98310>
# Celda: H82, Fórmula Excel: 30000/16, Función Python: <function <lambda> at 0x118a98430>
# Celda: H84, Fórmula Excel: H80-H81-H82-H83, Función Python: <function <lambda> at 0x118a98550>
# Celda: J85, Fórmula Excel: (J84+I84+H84+G84)*0.15, Función Python: <function <lambda> at 0x118a98670>
# Celda: J89, Fórmula Excel: J84-J85-J86-J87+J88, Función Python: <function <lambda> at 0x118a98790>
# Celda: J120, Fórmula Excel: J89*16.52, Función Python: <function <lambda> at 0x118a988b0>
# Celda: H86, Fórmula Excel: K96, Función Python: <function <lambda> at 0x118a989d0>
# Celda: H89, Fórmula Excel: H84-H85-H86-H87+H88, Función Python: <function <lambda> at 0x118a98af0>
# Celda: H120, Fórmula Excel: H89*16.52, Función Python: <function <lambda> at 0x118a98c10>
# Celda: O86, Fórmula Excel: R96, Función Python: <function <lambda> at 0x118a98d30>
# Celda: O82, Fórmula Excel: 30000/16, Función Python: <function <lambda> at 0x118a98e50>
# Celda: O83, Fórmula Excel: R95, Función Python: <function <lambda> at 0x118a98f70>
# Celda: O26, Fórmula Excel: 20000*0.075, Función Python: <function <lambda> at 0x118a99090>
# Celda: O11, Fórmula Excel: O16+O17+O19+O23+O24+O26+O15+O25, Función Python: <function <lambda> at 0x118a99240>
# Celda: O38, Fórmula Excel: O11*0.03, Función Python: <function <lambda> at 0x118a992d0>
# Celda: O39, Fórmula Excel: O11*0.03, Función Python: <function <lambda> at 0x118a993f0>
# Celda: O36, Fórmula Excel: O38+O39+O37, Función Python: <function <lambda> at 0x118a99510>
# Celda: O41, Fórmula Excel: O11+O36, Función Python: <function <lambda> at 0x118a99630>
# Celda: O81, Fórmula Excel: 'Costos Agricolas 01 ha'!O41, Función Python: <function <lambda> at 0x118a99750>
# Celda: O58, Fórmula Excel: O53+O55, Función Python: <function <lambda> at 0x118a99870>
# Celda: O57, Fórmula Excel: O58, Función Python: <function <lambda> at 0x118a99990>
# Celda: O80, Fórmula Excel: 'Costos Agricolas 01 ha'!O57, Función Python: <function <lambda> at 0x118a99ab0>
# Celda: O84, Fórmula Excel: O80-O81-O82-O83, Función Python: <function <lambda> at 0x118a99bd0>
# Celda: O85, Fórmula Excel: O84*0.15, Función Python: <function <lambda> at 0x118a99cf0>
# Celda: O89, Fórmula Excel: O84-O85-O86-O87+O88, Función Python: <function <lambda> at 0x118a99e10>
# Celda: O120, Fórmula Excel: O89*16.52, Función Python: <function <lambda> at 0x118a99f30>
# Celda: S58, Fórmula Excel: S53+S55, Función Python: <function <lambda> at 0x118a9a050>
# Celda: S57, Fórmula Excel: S58, Función Python: <function <lambda> at 0x118a9a170>
# Celda: S80, Fórmula Excel: 'Costos Agricolas 01 ha'!S57, Función Python: <function <lambda> at 0x118a9a290>
# Celda: S82, Fórmula Excel: 30000/16, Función Python: <function <lambda> at 0x118a9a3b0>
# Celda: S26, Fórmula Excel: 20000*0.075, Función Python: <function <lambda> at 0x118a9a4d0>
# Celda: S11, Fórmula Excel: S16+S17+S19+S23+S24+S26+S15+S25, Función Python: <function <lambda> at 0x118a9a680>
# Celda: S38, Fórmula Excel: S11*0.03, Función Python: <function <lambda> at 0x118a9a710>
# Celda: S39, Fórmula Excel: S11*0.03, Función Python: <function <lambda> at 0x118a9a830>
# Celda: S36, Fórmula Excel: S38+S39+S37, Función Python: <function <lambda> at 0x118a9a950>
# Celda: S41, Fórmula Excel: S11+S36, Función Python: <function <lambda> at 0x118a9aa70>
# Celda: S81, Fórmula Excel: 'Costos Agricolas 01 ha'!S41, Función Python: <function <lambda> at 0x118a9ab90>
# Celda: S84, Fórmula Excel: S80-S81-S82-S83, Función Python: <function <lambda> at 0x118a9acb0>
# Celda: S85, Fórmula Excel: S84*0.15, Función Python: <function <lambda> at 0x118a9add0>
# Celda: S89, Fórmula Excel: S84-S85-S86-S87+S88, Función Python: <function <lambda> at 0x118a9aef0>
# Celda: S120, Fórmula Excel: S89*16.52, Función Python: <function <lambda> at 0x118a9b010>
# Celda: V26, Fórmula Excel: 20000*0.075, Función Python: <function <lambda> at 0x118a9b130>
# Celda: V18, Fórmula Excel: 22*40, Función Python: <function <lambda> at 0x118a9b250>
# Celda: V11, Fórmula Excel: V15+V17+V18+V19+V23+V26+V24, Función Python: <function <lambda> at 0x118a9b370>
# Celda: V38, Fórmula Excel: V11*0.03, Función Python: <function <lambda> at 0x118a9b490>
# Celda: V39, Fórmula Excel: V11*0.03, Función Python: <function <lambda> at 0x118a9b5b0>
# Celda: V36, Fórmula Excel: V38+V39+V37, Función Python: <function <lambda> at 0x118a9b6d0>
# Celda: V41, Fórmula Excel: V11+V36, Función Python: <function <lambda> at 0x118a9b7f0>
# Celda: V81, Fórmula Excel: 'Costos Agricolas 01 ha'!V41, Función Python: <function <lambda> at 0x118a9b910>
# Celda: V58, Fórmula Excel: V53+V55, Función Python: <function <lambda> at 0x118a9ba30>
# Celda: V57, Fórmula Excel: V58, Función Python: <function <lambda> at 0x118a9bb50>
# Celda: V80, Fórmula Excel: 'Costos Agricolas 01 ha'!V57, Función Python: <function <lambda> at 0x118a9bc70>
# Celda: V82, Fórmula Excel: 30000/16, Función Python: <function <lambda> at 0x118a9bd90>
# Celda: V84, Fórmula Excel: V80-V81-V82-V83, Función Python: <function <lambda> at 0x118a9beb0>
# Celda: V85, Fórmula Excel: V84*0.15, Función Python: <function <lambda> at 0x118a84040>
# Celda: V89, Fórmula Excel: V84-V85-V86-V87+V88, Función Python: <function <lambda> at 0x118a84160>
# Celda: V120, Fórmula Excel: V89*16.52, Función Python: <function <lambda> at 0x118a84280>
#
# --- Raíces Originales ---
# Celda: M88, Valor: None
# Celda: M87, Valor: None
# Celda: M37, Valor: 300.0
# Celda: M23, Valor: 2800.0
# Celda: M15, Valor: 427.0
# Celda: M25, Valor: 400.0
# Celda: M17, Valor: 1730.0
# Celda: M19, Valor: 483.0
# Celda: M16, Valor: None
# Celda: M24, Valor: 1200.0
# Celda: F98, Valor: 30800.0
# Celda: H95, Valor: 0.07
# Celda: J94, Valor: 30800.0
# Celda: R88, Valor: None
# Celda: R24, Valor: 1200.0
# Celda: R17, Valor: 1734.0
# Celda: R16, Valor: None
# Celda: R15, Valor: 427.0
# Celda: R25, Valor: 400.0
# Celda: R23, Valor: 2800.0
# Celda: R19, Valor: 470.0
# Celda: R37, Valor: 300.0
# Celda: R83, Valor: None
# Celda: R86, Valor: None
# Celda: R87, Valor: None
# Celda: I37, Valor: 400.0
# Celda: I24, Valor: 980.0
# Celda: I19, Valor: 382.0
# Celda: I15, Valor: 350.0
# Celda: I17, Valor: 1200.0
# Celda: I23, Valor: 2000.0
# Celda: I25, Valor: 200.0
# Celda: I16, Valor: 50.0
# Celda: E45, Valor: 25.0
# Celda: I85, Valor: 0.0
# Celda: I88, Valor: None
# Celda: I87, Valor: None
# Celda: G88, Valor: 3800.0
# Celda: G57, Valor: 0.0
# Celda: G15, Valor: 350.0
# Celda: G19, Valor: 121.0
# Celda: G23, Valor: 1200.0
# Celda: G24, Valor: 750.0
# Celda: G17, Valor: 1000.0
# Celda: G25, Valor: 200.0
# Celda: G16, Valor: 200.0
# Celda: G37, Valor: 200.0
# Celda: G87, Valor: None
# Celda: G85, Valor: 0.0
# Celda: P87, Valor: None
# Celda: P15, Valor: 427.0
# Celda: P17, Valor: 1980.0
# Celda: P19, Valor: 480.0
# Celda: P24, Valor: 1200.0
# Celda: P25, Valor: 400.0
# Celda: P23, Valor: 2800.0
# Celda: P16, Valor: None
# Celda: P37, Valor: 300.0
# Celda: P88, Valor: None
# Celda: K23, Valor: 2800.0
# Celda: K16, Valor: None
# Celda: K25, Valor: 400.0
# Celda: K19, Valor: 454.0
# Celda: K15, Valor: 400.0
# Celda: K17, Valor: 1715.0
# Celda: K24, Valor: 1200.0
# Celda: K37, Valor: 300.0
# Celda: K88, Valor: None
# Celda: K87, Valor: None
# Celda: L88, Valor: None
# Celda: L16, Valor: None
# Celda: L17, Valor: 1723.0
# Celda: L24, Valor: 1200.0
# Celda: L25, Valor: 400.0
# Celda: L23, Valor: 2800.0
# Celda: L19, Valor: 483.0
# Celda: L15, Valor: 600.0
# Celda: L37, Valor: 300.0
# Celda: L87, Valor: None
# Celda: U16, Valor: None
# Celda: U19, Valor: 430.0
# Celda: U24, Valor: 1200.0
# Celda: U15, Valor: 427.0
# Celda: U17, Valor: 1734.0
# Celda: U23, Valor: 2800.0
# Celda: U25, Valor: 400.0
# Celda: U37, Valor: 300.0
# Celda: U83, Valor: None
# Celda: U87, Valor: None
# Celda: U88, Valor: None
# Celda: U86, Valor: None
# Celda: E85, Valor: None
# Celda: G34, Valor: None
# Celda: H52, Valor: None
# Celda: H22, Valor: None
# Celda: E86, Valor: None
# Celda: H37, Valor: 300.0
# Celda: H19, Valor: 300.0
# Celda: H23, Valor: 1500.0
# Celda: H24, Valor: 950.0
# Celda: H16, Valor: 50.0
# Celda: H15, Valor: 350.0
# Celda: H25, Valor: 200.0
# Celda: H17, Valor: 1100.0
# Celda: E29, Valor: 100.0
# Celda: H45, Valor: 0.0
# Celda: E84, Valor: None
# Celda: F85, Valor: None
# Celda: F84, Valor: None
# Celda: B23, Valor: None
# Celda: B28, Valor: None
# Celda: B19, Valor: None
# Celda: B26, Valor: None
# Celda: F86, Valor: None
# Celda: F88, Valor: None
# Celda: T15, Valor: 427.0
# Celda: T19, Valor: 481.0
# Celda: T16, Valor: None
# Celda: T25, Valor: 400.0
# Celda: T24, Valor: 1200.0
# Celda: T23, Valor: 2800.0
# Celda: T17, Valor: 1734.0
# Celda: T37, Valor: 300.0
# Celda: T83, Valor: None
# Celda: T88, Valor: None
# Celda: T87, Valor: None
# Celda: T86, Valor: None
# Celda: N88, Valor: None
# Celda: N24, Valor: 1200.0
# Celda: N19, Valor: 505.0
# Celda: N15, Valor: 427.0
# Celda: N25, Valor: 400.0
# Celda: N16, Valor: None
# Celda: N23, Valor: 2800.0
# Celda: N17, Valor: 1747.0
# Celda: N37, Valor: 300.0
# Celda: N87, Valor: None
# Celda: Q24, Valor: 1200.0
# Celda: Q19, Valor: 467.0
# Celda: Q15, Valor: 427.0
# Celda: Q23, Valor: 2800.0
# Celda: Q16, Valor: None
# Celda: Q17, Valor: 1734.0
# Celda: Q25, Valor: 400.0
# Celda: Q37, Valor: 300.0
# Celda: Q83, Valor: None
# Celda: Q88, Valor: None
# Celda: Q86, Valor: None
# Celda: Q87, Valor: None
# Celda: J88, Valor: None
# Celda: J25, Valor: 200.0
# Celda: J15, Valor: 400.0
# Celda: J19, Valor: 372.0
# Celda: J23, Valor: 2500.0
# Celda: J17, Valor: 1455.0
# Celda: J16, Valor: None
# Celda: J24, Valor: 1000.0
# Celda: J37, Valor: 400.0
# Celda: J87, Valor: None
# Celda: H88, Valor: 3800.0
# Celda: H87, Valor: None
# Celda: H85, Valor: 0.0
# Celda: O24, Valor: 1200.0
# Celda: O17, Valor: 1735.0
# Celda: O16, Valor: None
# Celda: O23, Valor: 2800.0
# Celda: O19, Valor: 510.0
# Celda: O15, Valor: 427.0
# Celda: O25, Valor: 400.0
# Celda: O37, Valor: 300.0
# Celda: O88, Valor: None
# Celda: O87, Valor: None
# Celda: S86, Valor: None
# Celda: S87, Valor: None
# Celda: S83, Valor: None
# Celda: S15, Valor: 427.0
# Celda: S25, Valor: 400.0
# Celda: S19, Valor: 467.0
# Celda: S16, Valor: None
# Celda: S23, Valor: 2800.0
# Celda: S17, Valor: 1734.0
# Celda: S24, Valor: 1200.0
# Celda: S37, Valor: 300.0
# Celda: S88, Valor: None
# Celda: V19, Valor: 480.0
# Celda: V24, Valor: 1200.0
# Celda: V17, Valor: 1734.0
# Celda: V23, Valor: 2200.0
# Celda: V15, Valor: 427.0
# Celda: V37, Valor: 300.0
# Celda: V83, Valor: None
# Celda: V87, Valor: None
# Celda: V88, Valor: None
# Celda: V86, Valor: None
#
# --- Iniciando Análisis de Sensibilidad para E123 ---
# Advertencia: Celda E123 no es raíz, no tiene fórmula ni valor numérico directo. Su valor es: =NPV(0.06,G120:V120)+E120+F120
#
# Valor base de E123: =NPV(0.06,G120:V120)+E120+F120
